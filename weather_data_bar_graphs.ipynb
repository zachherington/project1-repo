# %%
import pandas as pd

# %%
file_to_load = "ny_weather_0119-0619.csv"
weather_df = pd.read_csv(file_to_load)
weather_df
# Out:
#      Unnamed: 0        date  Avg Temp  Min Temp  Max Temp  Precipitation  \
# 0             0  2019-01-01      10.2       4.3      14.3            2.0
# 1             1  2019-01-02       3.6       1.6       4.9            0.0
# 2             2  2019-01-03       5.0      -0.1       7.1            0.0
# 3             3  2019-01-04       2.8      -1.7       7.7            0.0
# 4             4  2019-01-05       6.5       4.9       8.2           15.5
# ..          ...         ...       ...       ...       ...            ...
# 147         147  2019-05-28      20.3      17.1      24.3           19.6
# 148         148  2019-05-29      20.0      14.3      23.8           14.7
# 149         149  2019-05-30      16.1      14.3      19.9           13.2
# 150         150  2019-05-31      21.7      17.1      28.2            0.0
# 151         151  2019-06-01      22.0      17.1      26.0            0.0
#
#      Snowfall  Wind Direction  Wind Speed  Wind Peak Gust  Air Pressure  \
# ...

# %%
precipitation_df = weather_df.sort_values(by="Precipitation",ascending=False)
precipitation_df
# Out:
#      Unnamed: 0        date  Avg Temp  Min Temp  Max Temp  Precipitation  \
# 124         124  2019-05-05      13.1      11.0      14.3           38.9
# 131         131  2019-05-12      11.7       6.6      14.9           37.6
# 19           19  2019-01-20       1.6     -10.6       4.9           27.2
# 79           79  2019-03-21       7.3       5.5       8.8           25.4
# 104         104  2019-04-15      15.3       7.7      21.0           25.4
# ..          ...         ...       ...       ...       ...            ...
# 56           56  2019-02-26      -0.4      -3.9       4.3            0.0
# 55           55  2019-02-25       5.0      -2.2       6.0            0.0
# 52           52  2019-02-22       6.0       2.1       7.1            0.0
# 49           49  2019-02-19      -1.8      -5.0       2.7            0.0
# 151         151  2019-06-01      22.0      17.1      26.0            0.0
#
#      Snowfall  Wind Direction  Wind Speed  Wind Peak Gust  Air Pressure  \
# ...

# %%
final_precipitation_df = precipitation_df.iloc[:10]

# %%
final_precipitation_df.plot.bar(x="date",y="Precipitation")

# %%
snow_df = weather_df.sort_values(by="Snowfall",ascending=False)

# %%
final_snow_df = snow_df.iloc[:10]

# %%
final_snow_df.plot.bar(x="date",y="Snowfall")

# %%
wind_df = weather_df.sort_values(by="Wind Speed",ascending=False)

# %%
final_wind_df = wind_df.iloc[:10]

# %%
final_wind_df.plot.bar(x="date",y="Wind Speed")
